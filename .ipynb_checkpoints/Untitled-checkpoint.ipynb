# %% [markdown]
# ## Table of contents
#
# 1. Introduction
# 2. License
# 3. Required libraries
# 4. The problem
# 5. Strategy
# 6. Checking data
# 7. Cleaning data
# 8. Exploring data
#     a. map
#     b. HAM/ROS rivalry
#     c.
# 9. Creating DF for Regression/Classification
# 10. Predicting a champion
# 11. Conclusion

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create Tables

# %%
# Create a local SQLite database
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:')

# Import DB creation objects and initialize 
from sqlalchemy import Table, Column, Integer, String, Float, MetaData, ForeignKey, Date
meta = MetaData()

# Create tables

# Circuits
Table (
    'Circuits', meta,
    Column('circuitId', Integer, primary_key=True),
    Column('circuitRef', String),
    Column('name', String),
    Column('location', String),
    Column('country', String),
    Column('lat', Float),
    Column('lng', Float),
#     Column('alt', Integer),
#     Column('url', String)
)

# Races
Table (
    'Races', meta,
    Column('raceId', Integer, primary_key=True),
    Column('year', Integer),
    Column('round', Integer),
    Column('circuitId', ForeignKey('Circuits.circuitId')),
    Column('name', String),
    Column('date', Date),
    Column('time', String),
#     Column('url', String)
)

# Drivers
Table (
    'Drivers', meta,
    Column('driverId', Integer, primary_key=True),
    Column('driverRef', String),
#     Column('number', Integer),
#     Column('code', String),
    Column('forename', String),
    Column('surname', String),
    Column('dob', String),
    Column('nationality', String),
#     Column('url', String)
)

# Constructors
Table (
    'Constructors', meta,
    Column('constructorId', Integer, primary_key=True),
    Column('constructorRef', String),
    Column('name', String),
    Column('nationality', String),
#     Column('url', String)
)

# Status
Table (
    'Status', meta,
    Column('statusId', Integer, primary_key=True),
    Column('status', String)
)

# Results
Table (
    'Results', meta,
    Column('resultId', Integer, primary_key=True),
    Column('raceId', ForeignKey('Races.raceId')),
    Column('driverId', ForeignKey('Drivers.driverId')),
    Column('constructorId', ForeignKey('Constructors.constructorId')),
#     Column('number', Integer),
    Column('grid', Integer),
#     Column('position', Integer),
    Column('positionText', String),
    Column('positionOrder', Integer),
    Column('points', Integer),
    Column('laps', Integer),
    Column('time', String),
    Column('milliseconds', Integer),
    Column('fastestLap', Integer),
    Column('rank', Integer),
    Column('fastestLapTime', String),
    Column('fastestLapSpeed', Float),
    Column('statusId', ForeignKey('Status.statusId'))
)

# Driver Standings
Table (
    'DriverStandings', meta,
    Column('driverStandingsId', Integer, primary_key=True),
    Column('raceId', ForeignKey('Races.raceId')),
    Column('driverId', ForeignKey('Drivers.driverId')),
    Column('points', Integer),
#     Column('position', Integer),
    Column('positionText', String),
    Column('wins', Integer)
)

# Constructor Results
Table (
    'ConstructorResults', meta,
    Column('constructorResultsId', Integer, primary_key=True),
    Column('raceId', ForeignKey('Races.raceId')),
    Column('constructorId', ForeignKey('Constructors.constructorId')),
    Column('points', Integer),
    Column('status', String)
)

# Constructor Standings
Table (
    'ConstructorStandings', meta,
    Column('constructorStandingsId', Integer, primary_key=True),
    Column('raceId', ForeignKey('Races.raceId')),
    Column('constructorId', ForeignKey('Constructors.constructorId')),
    Column('points', Integer),
#     Column('position', Integer),
    Column('positionText', String),
    Column('wins', Integer)
)

# Pit Stops
Table (
    'PitStops', meta,
    Column('raceId', ForeignKey('Races.raceId')),
    Column('driverId', ForeignKey('Drivers.driverId')),
    Column('stop', Integer),
    Column('lap', Integer),
    Column('time', Date),
    Column('duration', String),
    Column('milliseconds', Integer)
)

Table (
    'Seasons', meta,
    Column('year', Integer),
#     Column('url', String)
)

# Create tables in database
meta.create_all(engine)

# %% [markdown]
# Read from csv files, drop unwanted columns and write the rest to database

# %%
def populate_table(fileName, tableName, drop=[]):
    pd.read_csv("formula-1-race-data-19502017/"+fileName, encoding="ISO-8859-1").drop(drop, axis=1).to_sql(
        tableName, engine, if_exists='append', index=False)
    
# Populate tables with .csv data

# Circuits
populate_table('circuits.csv', 'Circuits', ['alt', 'url'])

# Races
populate_table('races.csv', 'Races', ['url'])

# Drivers
populate_table('drivers.csv', 'Drivers', ['number', 'code', 'url'])

# Constructors
populate_table('constructors.csv', 'Constructors', ['url'])

# Status
populate_table('status.csv', 'Status')

# Status
populate_table('results.csv', 'Results', ['number', 'position'])

# Driver Standings
populate_table('driverStandings.csv', 'DriverStandings', ['position'])

# Constructor Results
populate_table('constructorResults.csv', 'ConstructorResults')

# Constructor Standings
populate_table('constructorStandings.csv', 'ConstructorStandings', ['position'])

# Pit Stops
populate_table('pitStops.csv', 'PitStops')

# Seasons
populate_table('seasons.csv', 'Seasons', ['url'])

# %% [markdown]
# Winning drivers ordered by amount of wins

# %%
winners = pd.read_sql_query(' '.join(
    [
        'SELECT r.driverId, d.forename, d.surname, count(r.driverId) AS wins',
        'FROM Results AS r',
        'JOIN Drivers AS d',
        'ON d.driverId = r.driverId',
        'WHERE r.positionText = "1"',
        'GROUP BY r.driverId',
        'ORDER BY wins ASC'
    ]), engine).set_index('driverId')
winners
# Out:
#            forename     surname  wins
# driverId
# 5            Heikki  Kovalainen     1
# 9            Robert      Kubica     1
# 15            Jarno      Trulli     1
# 44          Olivier       Panis     1
# 55             Jean       Alesi     1
# ...             ...         ...   ...
# 102          Ayrton       Senna    41
# 117           Alain       Prost    51
# 20        Sebastian      Vettel    53
# 1             Lewis    Hamilton    84
# 30          Michael  Schumacher    91
#
# [108 rows x 3 columns]

# %%
plt.figure(figsize=(11,11))
plt.bar(winners['surname'][-10:], winners['wins'][-10:])
plt.show()

# %%
print(winners['wins'].mean())
plt.figure(figsize=(11,11))
plt.scatter(range(len(winners['wins'])), winners['wins'])
plt.axhline(y=winners['wins'].mean(), color='r', linestyle='-')
plt.show()
# Out:
# 9.453703703703704

# %% [markdown]
# Championship order for any year

# %%
def getStandingsForYear(year):
    return pd.read_sql_query(' '.join([
        f'SELECT *, SUM(res.points) as TotalPoints',
        'FROM Results AS res',
        'JOIN Races AS rc',
        'ON rc.raceId = res.raceId',
        'JOIN Drivers as d',
        'ON d.driverId = res.driverId',
        f'WHERE rc.year = {year}',
        'GROUP BY res.driverId',
        'ORDER BY TotalPoints DESC'
    ]), engine)

getStandingsForYear(2019)
# Out:
#     resultId  raceId driverId  constructorId  grid positionText  \
# 0      24203    1010        1            131     1            2
# 1      24202    1010      822            131     2            1
# 2      24204    1010      830              9     4            3
# 3      24206    1010      844              6     5            5
# 4      24205    1010       20              6     3            4
# 5      24221    1010      832              1    18            R
# 6      24212    1010      842              9    17           11
# 7      24215    1010      846              5    13           14
# 8      24220    1010      817              4    12            R
# 9      24214    1010      815            211    10           13
# 10     24213    1010      847              1     8           12
# 11     24209    1010        8             51     9            8
# 12     24211    1010      826              5    15           10
# 13     24208    1010      807              4    11            7
# 14     24210    1010      840            211    16            9
# 15     24207    1010      825            210     7            6
# 16     24216    1010      841             51    14           15
# 17     24219    1010      154            210     6            R
# 18     24218    1010        9              3    20           17
# 19     24217    1010      848              3    19           16
#
#     positionOrder  points  laps         time  ...                   name  \
# 0               2      18    58      +20.886  ...  Australian Grand Prix
# 1               1      26    58  1:25:27.325  ...  Australian Grand Prix
# 2               3      15    58      +22.520  ...  Australian Grand Prix
# 3               5      10    58      +58.203  ...  Australian Grand Prix
# 4               4      12    58      +57.109  ...  Australian Grand Prix
# 5              20       0     9         None  ...  Australian Grand Prix
# 6              11       0    57         None  ...  Australian Grand Prix
# 7              14       0    57         None  ...  Australian Grand Prix
# 8              19       0    28         None  ...  Australian Grand Prix
# 9              13       0    57         None  ...  Australian Grand Prix
# 10             12       0    57         None  ...  Australian Grand Prix
# 11              8       4    57         None  ...  Australian Grand Prix
# 12             10       1    57         None  ...  Australian Grand Prix
# 13              7       6    57         None  ...  Australian Grand Prix
# 14              9       2    57         None  ...  Australian Grand Prix
# 15              6       8    58    +1:27.156  ...  Australian Grand Prix
# 16             15       0    57         None  ...  Australian Grand Prix
# 17             18       0    29         None  ...  Australian Grand Prix
# 18             17       0    55         None  ...  Australian Grand Prix
# 19             16       0    56         None  ...  Australian Grand Prix
#
#           date      time driverId        driverRef   forename     surname  \
# 0   17-03-2019  05:10:00        1         hamilton      Lewis    Hamilton
# 1   17-03-2019  05:10:00      822           bottas   Valtteri      Bottas
# 2   17-03-2019  05:10:00      830   max_verstappen        Max  Verstappen
# 3   17-03-2019  05:10:00      844  charles_leclerc    Charles     Leclerc
# 4   17-03-2019  05:10:00       20           vettel  Sebastian      Vettel
# 5   17-03-2019  05:10:00      832            sainz     Carlos       Sainz
# 6   17-03-2019  05:10:00      842            gasly     Pierre       Gasly
# 7   17-03-2019  05:10:00      846       alex_albon  Alexander       Albon
# 8   17-03-2019  05:10:00      817        ricciardo     Daniel   Ricciardo
# 9   17-03-2019  05:10:00      815            perez     Sergio       Pérez
# 10  17-03-2019  05:10:00      847     lando_norris      Lando      Norris
# 11  17-03-2019  05:10:00        8        raikkonen       Kimi   Räikkönen
# 12  17-03-2019  05:10:00      826            kvyat     Daniil       Kvyat
# 13  17-03-2019  05:10:00      807       hulkenberg       Nico  Hülkenberg
# 14  17-03-2019  05:10:00      840           stroll      Lance      Stroll
# 15  17-03-2019  05:10:00      825  kevin_magnussen      Kevin   Magnussen
# 16  17-03-2019  05:10:00      841       giovinazzi    Antonio  Giovinazzi
# 17  17-03-2019  05:10:00      154         grosjean     Romain    Grosjean
# 18  17-03-2019  05:10:00        9           kubica     Robert      Kubica
# 19  17-03-2019  05:10:00      848    george_russel     George      Russel
#
#            dob  nationality  TotalPoints
# 0   07/01/1985      British          413
# 1   28/08/1989      Finnish          326
# 2   30/09/1997        Dutch          278
# 3   16/10/1997   Monegasque          264
# 4   03/07/1987       German          240
# 5   01/09/1994      Spanish           96
# 6   07/02/1996       French           95
# 7   23/03/1996         Thai           92
# 8   01/07/1989   Australian           54
# 9   26/01/1990      Mexican           52
# 10  13/11/1999      British           49
# 11  17/10/1979      Finnish           43
# 12  26/04/1994      Russian           37
# 13  19/08/1987       German           37
# 14  29/10/1998     Canadian           21
# 15  05/10/1992       Danish           20
# 16  14/12/1993      Italian           14
# 17  17/04/1986       French            8
# 18  07/12/1984       Polish            1
# 19  15/02/1998      British            0
#
# [20 rows x 30 columns]

# %% [markdown]
# List of drivers world champions by year

# %%
champions = {'driverId': [], 'year': [], 'winner': []}

for year in np.sort(pd.read_sql_query('SELECT * FROM Seasons',engine)['year'].values):
    standings = getStandingsForYear(year)
    champions['year'].append(year)
    champions['winner'].append(' '.join(standings.iloc[0][['forename', 'surname']].to_numpy()))
    champions['driverId'].append(standings.iloc[0]['driverId'].to_numpy()[0])

champs = pd.DataFrame(champions)
champs
# Out:
#     driverId  year          winner
# 0        642  1950     Nino Farina
# 1        579  1951     Juan Fangio
# 2        647  1952  Alberto Ascari
# 3        647  1953  Alberto Ascari
# 4        579  1954     Juan Fangio
# ..       ...   ...             ...
# 65         1  2015  Lewis Hamilton
# 66         3  2016    Nico Rosberg
# 67         1  2017  Lewis Hamilton
# 68         1  2018  Lewis Hamilton
# 69         1  2019  Lewis Hamilton
#
# [70 rows x 3 columns]

# %% [markdown]
# World champions ordered by number of championships won

# %%
champCount = {k: 0 for k in champs['winner'].unique()}
for i, row in champs.iterrows():
    champCount[row['winner']]+=1
championships = pd.DataFrame({'driverId': [x for x in champs['driverId'].unique()], 
              'Drivers': list(champCount.keys()), 
              'Championships': list(champCount.values())}).sort_values(by=['Championships'], ascending=False)
championships
# Out:
#     driverId             Drivers  Championships
# 22        30  Michael Schumacher              7
# 28         1      Lewis Hamilton              6
# 19       117         Alain Prost              5
# 1        579         Juan Fangio              5
# 30        20    Sebastian Vettel              4
# 4        356        Jack Brabham              3
# 6        289         Graham Hill              3
# 17       137       Nelson Piquet              3
# 9        328      Jackie Stewart              3
# 12       182          Niki Lauda              3
# 7        373           Jim Clark              2
# 2        647      Alberto Ascari              2
# 11       224  Emerson Fittipaldi              2
# 26         4     Fernando Alonso              2
# 25        57       Mika Häkkinen              2
# 20       102        Ayrton Senna              2
# 23        71          Damon Hill              1
# 0        642         Nino Farina              1
# 24        35  Jacques Villeneuve              1
# 29        18       Jenson Button              1
# 27         8      Kimi Räikkönen              1
# 16       178          Alan Jones              1
# 21        95       Nigel Mansell              1
# 18       177        Keke Rosberg              1
# 15       222      Jody Scheckter              1
# 14       207      Mario Andretti              1
# 13       231          James Hunt              1
# 10       358        Jochen Rindt              1
# 8        304         Denny Hulme              1
# 5        403           Phil Hill              1
# 3        578       Mike Hawthorn              1
# 31         3        Nico Rosberg              1

# %% [markdown]
# Race wins for a year

# %%
def getWinsForYear(year):
    return pd.read_sql_query(' '.join([
        'SELECT res.*, COUNT(res.positionText) as RaceWins',
        'FROM Results AS res',
        'JOIN Races AS rc',
        'ON rc.raceId = res.raceId',
        'JOIN Drivers as d',
        'ON d.driverId = res.driverId',
        f'WHERE rc.year = {year}',
        'AND res.positionText = "1"',
        'GROUP BY res.driverId',
        'ORDER BY RaceWins DESC'
    ]), engine)

getWinsForYear(1982)
# Out:
#     resultId  raceId  driverId  constructorId  grid positionText  \
# 0      11173     470       202              6     4            1
# 1      11187     471       187              1    10            1
# 2      11142     469       182              1     2            1
# 3      11369     477       163              4     1            1
# 4      11080     467       117              4     5            1
# 5      11456     480       177              3     8            1
# 6      11398     478       175              6     5            1
# 7      11427     479       173             32     7            1
# 8      11279     474       137             34     4            1
# 9      11219     472       119             34     2            1
# 10     11515     482       105             25     3            1
#
#     positionOrder  points  laps     time  milliseconds fastestLap  rank  \
# 0               1       9    60  36:38.9       5798887       None  None
# 1               1       9    70  35:42.0       5741995       None  None
# 2               1       9    75  58:25.3       7105318       None  None
# 3               1       9    54  33:33.2       5613217       None  None
# 4               1       9    77  32:08.4       5528401       None  None
# 5               1       9    80  32:41.1       5561087       None  None
# 6               1       9    45  27:25.2       5245178       None  None
# 7               1       9    53  25:02.2       5102212       None  None
# 8               1       9    70  46:39.6       6399577       None  None
# 9               1       9    76  54:11.3       6851259       None  None
# 10              1       9    75  41:56.9       6116888       None  None
#
#    fastestLapTime fastestLapSpeed  statusId  RaceWins
# 0            None            None         1         2
# 1            None            None         1         2
# 2            None            None         1         2
# 3            None            None         1         2
# 4            None            None         1         2
# 5            None            None         1         1
# 6            None            None         1         1
# 7            None            None         1         1
# 8            None            None         1         1
# 9            None            None         1         1
# 10           None            None         1         1

# %% [markdown]
# Race wins to win a championship

# %%
rw = []

for i, wc in champs.iterrows():
    year = getWinsForYear(wc['year'])
    rw.append(int(year[wc['driverId']==year['driverId']]['RaceWins'].to_string(index=False)))
champs['RaceWins'] = rw
champs.sort_values(by=['RaceWins'], ascending=False)
# Out:
#     driverId  year              winner  RaceWins
# 54        30  2004  Michael Schumacher        13
# 63        20  2013    Sebastian Vettel        13
# 69         1  2019      Lewis Hamilton        11
# 64         1  2014      Lewis Hamilton        11
# 61        20  2011    Sebastian Vettel        11
# ..       ...   ...                 ...       ...
# 9        356  1959        Jack Brabham         2
# 17       304  1967         Denny Hulme         2
# 11       403  1961           Phil Hill         2
# 32       177  1982        Keke Rosberg         1
# 8        578  1958       Mike Hawthorn         1
#
# [70 rows x 4 columns]

# %%
print(champs['RaceWins'].mean())

plt.scatter(champs['year'], champs['RaceWins'])
plt.axhline(y=champs['RaceWins'].mean(), color='r', linestyle='-')
plt.show()
# Out:
# 5.9

# %% [markdown]
# Races to win a championship is a bit arbitrary because the total amount of races per season varies. Better to look at wins/races ratio

# %%
def getTotalRacesInYear(year):
    return pd.read_sql_query(' '.join([
        'SELECT COUNT(*) AS Races',
        'FROM Races AS ra',
        f'WHERE ra.year = {year}'
    ]), engine)['Races'].values[0]

getTotalRacesInYear(2019)
# Out:
# 21

# %%
champs['totalRaces'] = [getTotalRacesInYear(x) for x in champs['year']]
champs['win/race Ratio'] = [x['RaceWins']/x['totalRaces'] for i, x in champs.iterrows()]
champs.sort_values(by=['win/race Ratio'])
# Out:
#     driverId  year              winner  RaceWins  totalRaces  win/race Ratio
# 32       177  1982        Keke Rosberg         1          16        0.062500
# 8        578  1958       Mike Hawthorn         1          11        0.090909
# 27       182  1977          Niki Lauda         3          17        0.176471
# 17       304  1967         Denny Hulme         2          11        0.181818
# 37       137  1987       Nelson Piquet         3          16        0.187500
# ..       ...   ...                 ...       ...         ...             ...
# 4        579  1954         Juan Fangio         6           9        0.666667
# 63        20  2013    Sebastian Vettel        13          19        0.684211
# 13       373  1963           Jim Clark         7          10        0.700000
# 54        30  2004  Michael Schumacher        13          18        0.722222
# 2        647  1952      Alberto Ascari         6           8        0.750000
#
# [70 rows x 6 columns]

# %% [markdown]
# Average win/race ratio to win the championship

# %%
print(champs['win/race Ratio'].mean())
plt.plot(champs['year'], champs['win/race Ratio'])
plt.axhline(y=champs['win/race Ratio'].mean(), color='r', linestyle='-')
plt.show()
# Out:
# 0.4071837417950863

# %% [markdown]
# Average win/race ratio per decade

# %%
plt.plot(champs['year'], champs['win/race Ratio'])
plt.plot(champs['year'], [[champs[champs['year'].astype(str).str.contains(str(x))]['win/race Ratio'].mean() for x in range(195,202)][i//10] for i, x in champs.iterrows()], color='r')
plt.show()

# %% [markdown]
# Carreer win/race stats

# %%
def joinQueries(queries):
    joinQuery = queries[0]
    for i in queries[1:]:
        joinQuery = joinQuery.join(i)
    return joinQuery

# %%
winLossDrivers = joinQueries([
    pd.read_sql_query(' '.join([
        'SELECT driverId, forename, surname',
        'FROM Drivers'
    ]), engine).set_index('driverId'),
     pd.read_sql_query(' '.join([
        'SELECT re.driverId, COUNT(re.resultId) AS Entries',
        'FROM Results AS re',
        'GROUP BY re.driverId'
    ]), engine).set_index('driverId'),
    pd.read_sql_query(' '.join([
        'SELECT re.driverId, COUNT(re.resultId) AS Wins',
        'FROM Results AS re',
        'WHERE re.positionText = "1"',
        'GROUP BY re.driverId'
    ]), engine).set_index('driverId')
]).fillna(0)

winLossDrivers['ratio'] = [x['Wins']/x['Entries'] for i, x in winLossDrivers.iterrows()]
winLossDrivers.sort_values(by=['ratio'], ascending=False)
# Out:
#          forename   surname  Entries  Wins     ratio
# driverId
# 766           Lee   Wallard        2   1.0  0.500000
# 579          Juan    Fangio       58  24.0  0.413793
# 657          Bill  Vukovich        5   2.0  0.400000
# 647       Alberto    Ascari       36  13.0  0.361111
# 373           Jim     Clark       72  25.0  0.347222
# ...           ...       ...      ...   ...       ...
# 319          José    Dolhem        3   0.0  0.000000
# 321         Derek      Bell       14   0.0  0.000000
# 322         David     Hobbs        7   0.0  0.000000
# 323        Dieter   Quester        1   0.0  0.000000
# 848        George    Russel       21   0.0  0.000000
#
# [847 rows x 5 columns]

# %%
wlpt = winLossDrivers.drop(winLossDrivers[winLossDrivers['Wins'] < 1].index)
plt.scatter(wlpt.index, wlpt['ratio'])
plt.show()

# %% [markdown]
# Average finishing position for drivers

# %%
avgFinPos = pd.read_sql_query(' '.join([
    'SELECT res.driverId, drv.forename, drv.surname, AVG(res.positionOrder) AS AverageFinishingPosition',
    'FROM Results AS res',
    'JOIN Drivers as drv',
    'ON drv.driverId = res.driverId',
    'GROUP BY res.driverId',
]), engine).set_index('driverId')
avgFinPos.sort_values(by=['AverageFinishingPosition'])
# Out:
#          forename     surname  AverageFinishingPosition
# driverId
# 591        George       Amick                  2.000000
# 802        Dorino    Serafini                  2.000000
# 766           Lee     Wallard                  3.500000
# 786         Luigi     Fagioli                  4.375000
# 579          Juan      Fangio                  4.793103
# ...           ...         ...                       ...
# 161        Volker     Weidler                 34.700000
# 266         Brian     McGuire                 35.000000
# 164       Joachim  Winkelhock                 36.571429
# 492        Menato       Boffa                 38.000000
# 134        Enrico   Bertaggia                 38.833333
#
# [847 rows x 3 columns]

# %% [markdown]
# Number of finishes for drivers

# %%
finishes = pd.read_sql_query(' '.join([
    'SELECT r.driverId, COUNT(r.driverId) AS Finishes',
    'From Results AS r',
    'WHERE r.positionText != "R"',
    'AND r.positionText != "D"',
    'AND r.positionText != "F"',
    'GROUP BY r.driverId'
]), engine).set_index('driverId')
finishes
# Out:
#           Finishes
# driverId
# 1              226
# 2              139
# 3              177
# 4              256
# 5               93
# ...            ...
# 844             34
# 845             18
# 846             20
# 847             17
# 848             19
#
# [694 rows x 1 columns]

# %% [markdown]
# Number of entries for drivers

# %%
entries = pd.read_sql_query(' '.join([
    'SELECT r.driverId, COUNT(r.driverId) AS Entries',
    'FROM Results AS r',
    'GROUP BY r.driverId'
]), engine).set_index('driverId')
entries
# Out:
#           Entries
# driverId
# 1             250
# 2             184
# 3             206
# 4             314
# 5             112
# ...           ...
# 844            42
# 845            21
# 846            21
# 847            21
# 848            21
#
# [847 rows x 1 columns]

# %%
finEntRatio = finishes.join(entries)
finEntRatio['Finishes/Entries'] = [x['Finishes']/x['Entries'] for i, x in finEntRatio.iterrows()]
finEntRatio
# Out:
#           Finishes  Entries  Finishes/Entries
# driverId
# 1              226      250          0.904000
# 2              139      184          0.755435
# 3              177      206          0.859223
# 4              256      314          0.815287
# 5               93      112          0.830357
# ...            ...      ...               ...
# 844             34       42          0.809524
# 845             18       21          0.857143
# 846             20       21          0.952381
# 847             17       21          0.809524
# 848             19       21          0.904762
#
# [694 rows x 3 columns]

# %% [markdown]
# Number of pole positions for drivers

# %%
poles = pd.read_sql_query(' '.join([
    'SELECT res.driverId, COUNT(res.resultId) AS polePositions',
    'FROM Results AS res',
    'WHERE res.grid = 1',
    'GROUP BY res.driverId'
]), engine).set_index('driverId')
poles
# Out:
#           polePositions
# driverId
# 1                    88
# 2                     1
# 3                    30
# 4                    22
# 5                     1
# ...                 ...
# 813                   1
# 817                   3
# 822                  11
# 830                   2
# 844                   7
#
# [105 rows x 1 columns]

# %% [markdown]
# Average start position

# %%
gridPos = pd.read_sql_query(' '.join([
    'SELECT r.driverId, AVG(r.grid) AS AverageGridPosition',
    'FROM Results AS r',
    'GROUP BY r.driverId'
]), engine).set_index('driverId')
gridPos
# Out:
#           AverageGridPosition
# driverId
# 1                    3.852000
# 2                   11.336957
# 3                    6.902913
# 4                    8.500000
# 5                   13.741071
# ...                       ...
# 844                  8.357143
# 845                 16.285714
# 846                  9.238095
# 847                  9.333333
# 848                 16.761905
#
# [847 rows x 1 columns]

# %% [markdown]
# Is Champion

# %%
isChamp = pd.DataFrame({'driverId': range(1,848), 'isChamp': np.array([row['driverId'] in championships['driverId'].to_numpy() 
                  for i, row in pd.read_sql_query(' '.join(['SELECT driverId FROM Drivers']), engine).iterrows()])}).set_index('driverId')

isChamp
# Out:
#           isChamp
# driverId
# 1            True
# 2           False
# 3            True
# 4            True
# 5           False
# ...           ...
# 843         False
# 844         False
# 845         False
# 846         False
# 847         False
#
# [847 rows x 1 columns]

# %% [markdown]
# Master dataframe

# %%
master = joinQueries(
    [
        avgFinPos,
        finishes,
        entries,
        finEntRatio[['Finishes/Entries']],
        championships.set_index('driverId')[['Championships']], 
        poles,
        gridPos,
        isChamp
    ]
).fillna(0)
master
# Out:
#            forename     surname  AverageFinishingPosition  Finishes  Entries  \
# driverId
# 1             Lewis    Hamilton                  4.984000     226.0      250
# 2              Nick    Heidfeld                 10.722826     139.0      184
# 3              Nico     Rosberg                  8.252427     177.0      206
# 4          Fernando      Alonso                  8.229299     256.0      314
# 5            Heikki  Kovalainen                 13.285714      93.0      112
# ...             ...         ...                       ...       ...      ...
# 844         Charles     Leclerc                  8.976190      34.0       42
# 845          Sergey    Sirotkin                 15.523810      18.0       21
# 846       Alexander       Albon                  9.333333      20.0       21
# 847           Lando      Norris                 11.333333      17.0       21
# 848          George      Russel                 15.809524      19.0       21
#
#           Finishes/Entries  Championships  polePositions  AverageGridPosition  \
# driverId
# 1                 0.904000            6.0           88.0             3.852000
# 2                 0.755435            0.0            1.0            11.336957
# 3                 0.859223            1.0           30.0             6.902913
# 4                 0.815287            2.0           22.0             8.500000
# 5                 0.830357            0.0            1.0            13.741071
# ...                    ...            ...            ...                  ...
# 844               0.809524            0.0            7.0             8.357143
# 845               0.857143            0.0            0.0            16.285714
# 846               0.952381            0.0            0.0             9.238095
# 847               0.809524            0.0            0.0             9.333333
# 848               0.904762            0.0            0.0            16.761905
#
#          isChamp
# driverId
# 1           True
# 2          False
# 3           True
# 4           True
# 5          False
# ...          ...
# 844        False
# 845        False
# 846        False
# 847        False
# 848            0
#
# [847 rows x 10 columns]

# %%
pd.read_sql_query(' '.join([
    'SELECT * FROM Results WHERE driverId = 591'
]), engine)
# Out:
#    resultId  raceId  driverId  constructorId  grid positionText  \
# 0     18544     768       591            108    25            2
#
#    positionOrder  points  laps   time  milliseconds fastestLap  rank  \
# 0              2       6   200  27.63      13481430       None  None
#
#   fastestLapTime fastestLapSpeed  statusId
# 0           None            None         1

# %% [markdown]
# Hamilton - Rosberg: Rivalry

# %%
#All races in the year 2016
races_2016 = pd.read_sql_query(' '.join([
    'SELECT r.raceId, r.circuitId',
    'FROM Races AS r',
    'WHERE r.year == 2016'
]), engine).set_index('raceId')

#Get all circuit to use as x-axis
circuit = pd.read_sql_query(' '.join([
    'SELECT c.name',
    'FROM Circuits AS c'
]), engine)

#Driver standing of races during 2016 season
driver_standings = pd.read_sql_query(' '.join([
    'SELECT *',
    'FROM DriverStandings As ds',
    'WHERE ds.raceId <= 968 AND ds.raceId >= 948'
]), engine)

#Join together races and circuits to use circuit name for x-axis
races_circuits = pd.read_sql_query(' '.join([
    'SELECT r.raceId, c.name, c.location, c.country',
    'FROM Circuits AS c',
    'JOIN Races AS r',
    'ON r.circuitId == c.circuitId',
    'WHERE r.year == 2016'
]), engine)


#Drop all drivers that do not have Rosberg's id, merge with races and circuit and sort by raceId to
#get the season in order
rosberg = driver_standings.drop(driver_standings[(driver_standings.driverId != 3)].index)
rosberg = rosberg.merge(races_circuits, on='raceId', how='left').set_index('raceId')
rosberg.sort_values(by=['raceId'], inplace=True)

#Drop all drivers that do not have Hamilton's id, merge with races and circuit and sort by raceId to
#get the season in order
hamilton = driver_standings.drop(driver_standings[(driver_standings.driverId != 1)].index)
hamilton = hamilton.merge(races_circuits, on='raceId', how='left').set_index('raceId')
hamilton.sort_values(by=['raceId'], inplace=True)

#Set figure size and face color
fig =plt.figure(figsize=(16,8))
ax = plt.axes(facecolor='#F0F0F0')
ax.set_axisbelow(True)

# draw solid white grid lines
plt.grid(color='w', linestyle='solid')

#plotting Rosberg
plt.plot(rosberg.country, rosberg.points, lw=6, alpha=0.6, color='#DC493A', label="Nico Rosberg")
plt.scatter(rosberg.country, rosberg.points, color='k', zorder=5)

#plotting Hamilton
plt.scatter(hamilton.country, hamilton.points, color='k', zorder=5)
plt.plot(hamilton.country, hamilton.points, lw=6, alpha=0.6, color='#006494', label="Hamilton")

#Setting labels, title, and legend
plt.xlabel('Races', fontsize=12, labelpad=16)
plt.ylabel('Points',fontsize=12, labelpad=16)
plt.title('Points accumulated during season 2016', fontsize=18)
fig.tight_layout()
plt.legend(loc=0)
plt.show()
